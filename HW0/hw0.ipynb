# %% [markdown]
# ## Homework 0: Programming with Python (1)

# %% [markdown]
# ### About this assignment:
# This homework is to test your python progrmming skills in visualization. Data preprocessing and visualizatin are extremely important to explore and understand the data you are working on. This is usually a step before we analyze the data using machine learning technique.
#
# We are going to use the Iris dataset for this assignment. You can use either Matplotlib or Seaborn, depending on your preference.

# %% [markdown]
# ![Getting Started](iris_2.jpeg)

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# #### Import packages

# %%
# importing pandas, numpy, matplotlib and seaborn

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Import data

# %%
# importing Iris dataset
iris = pd.read_csv('iris.csv')

# %%
# displaying data
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  Setosa
# 1            4.9           3.0            1.4           0.2  Setosa
# 2            4.7           3.2            1.3           0.2  Setosa
# 3            4.6           3.1            1.5           0.2  Setosa
# 4            5.0           3.6            1.4           0.2  Setosa

# %% [markdown]
# #### 1(a)
# rubric={points:1}
#
# Change the column names to
# 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'
#
# Hint: use df.columns

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(a)
#
# </div>

# %%
dataframe = pd.DataFrame(iris)

iris.rename(columns= {'sepal.length':'SepalLengthCm'}, inplace=True)

iris.rename(columns= {'sepal.width':'SepalWidthCm'}, inplace=True)

iris.rename(columns= {'petal.length':'PetalLengthCm'}, inplace=True)

iris.rename(columns= {'petal.width':'PetalWidthCm'}, inplace=True)

iris.rename(columns= {'variety':'Species'}, inplace=True)

iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  Setosa
# 1            4.9           3.0            1.4           0.2  Setosa
# 2            4.7           3.2            1.3           0.2  Setosa
# 3            4.6           3.1            1.5           0.2  Setosa
# 4            5.0           3.6            1.4           0.2  Setosa

# %% [markdown]
# #### 1(b)
# rubric={points:1}
#
# What are the unique species in the Iris data? Hint: use unique()

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(b)
#
# </div>

# %%
#This data set has three varities of Iris plant.
print(iris.Species.unique())
# Out:
# ['Setosa' 'Versicolor' 'Virginica']

# %% [markdown]
# Summarize the iris data

# %%
iris.describe(include='all')
# Out:
#         SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# count      150.000000    150.000000     150.000000    150.000000     150
# unique            NaN           NaN            NaN           NaN       3
# top               NaN           NaN            NaN           NaN  Setosa
# freq              NaN           NaN            NaN           NaN      50
# mean         5.843333      3.057333       3.758000      1.199333     NaN
# std          0.828066      0.435866       1.765298      0.762238     NaN
# min          4.300000      2.000000       1.000000      0.100000     NaN
# 25%          5.100000      2.800000       1.600000      0.300000     NaN
# 50%          5.800000      3.000000       4.350000      1.300000     NaN
# 75%          6.400000      3.300000       5.100000      1.800000     NaN
# max          7.900000      4.400000       6.900000      2.500000     NaN

# %% [markdown]
# #### 1(c)
# rubric={points:1}
#
# Does the Iris data have missing values?
#
# Hint: use isnull() and any() or sum()

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(c)
#
# </div>

# %%
print(any(iris.isnull()))
# Out:
# True

# %% [markdown]
# #### 1(d)
# rubric={points:1}
#
# How many samples are there for each Iris species?
#
# Hint: use value_counts()

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(d)
#
# </div>

# %%
print(iris.Species.value_counts())
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# Check the number of non-zero values and datatype of different features using info()

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Make a bar plot for (the size) of each feature

# %%
#There is not any missing value in this dataset
import missingno as msno
msno.bar(iris,figsize=(8,6),color='skyblue')
plt.show()

# %% [markdown]
# ### Data visualization

# %% [markdown]
# 1. Scatterplot

# %% [markdown]
# ***
# A scatter plot is a two-dimensional data visualization that uses dots to represent the values obtained for two different variables — one plotted along the x-axis and the other plotted along the y-axis we can plot the scatter plot between any two features. i’am taking an example of petal length and petal width.
# ***

# %% [markdown]
# #### 1(e)
# rubric={points:1}
#
# Make a scatter plot of SepalLengthCm and SepalWidthCm, grouped by Species
#
# Hint: use scatter in Matplotlib or relplot in Seaborn

# %%
splot = sns.load_dataset("iris")

splot.rename(columns= {'sepal_length':'SepalLengthCm'}, inplace=True)

splot.rename(columns= {'sepal_width':'SepalWidthCm'}, inplace=True)

splot.rename(columns= {'petal_length':'PetalLengthCm'}, inplace=True)

splot.rename(columns= {'petal_width':'PetalWidthCm'}, inplace=True)

splot.rename(columns= {'species':'Species'}, inplace=True)

sns.relplot(data = splot, x = "SepalLengthCm", y = "SepalWidthCm", hue = "Species")

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(e)
#
# </div>

# %%
#See above
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### 1(f)
# rubric={points:1}
#
# Make a scatter plot of PetalLengthCm and PetalWidthCm, grouped by Species
#
# Hint: use scatter in Matplotlib or relplot in Seaborn

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(f)
#
# </div>

# %%
sns.relplot(data = splot, x = "PetalLengthCm", y = "PetalWidthCm", hue = "Species")

# %% [markdown]
# #### 1(g)
# rubric={points:1}
#
# Compare the plots of Petal Features and Sepal Features, what is your conclusion?

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(g)
#
# </div>

# %% [markdown]
# Setosas seem to have smaller petals and greater sepal width than versicolor or virginica. Additionally, versicolor and virginica seem to follow similar trends to one another, with virginica tending toward higher values on both metrics.

# %% [markdown]
# 2.2 Pairplot

# %% [markdown]
# ***
# Pair Plots are a really simple (one-line-of-code simple!) way to visualize relationships between each variable. It produces a matrix of relationships between each variable in your data for an instant examination of our data. pair plot gives scatter plot of different features. pair plot for iris data set.
# ***

# %% [markdown]
# #### 1(h)
# rubric={points:1}
#
# Make pairwise plots for each feature of the data
#
# Hint: use pairplot in Seaborn

# %%
sns.pairplot(splot)

# %% [markdown]
# #### Observations

# %% [markdown]
# From the graph we can see the scatter plot between the any two features and the distributions.
# From the distributions above petal length is separating the iris setosa from remaining.
# From plot between petal length and petal width we can separate the flowers.
# ***

# %% [markdown]
# 2.3 BoxPlot

# %% [markdown]
# ***
# Boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed.
# ***

# %% [markdown]
# ![Getting Started](boxplot.png)

# %% [markdown]
# #### 1(i)
# rubric={points:1}
#
# Make a boxplot for each of the four features over the three species. The y axis is the feature and x axis is the three species
#
# Hint: use boxplot in Seaborn

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(i)
#
# </div>

# %%
sns.boxplot(data = splot, x = "Species", y = "SepalLengthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(data = splot, x = "Species", y = "SepalWidthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(data = splot, x = "Species", y = "PetalLengthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(data = splot, x = "Species", y = "PetalWidthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# #### Distribution of SepalLengthCm, SepalWidthCm, PetalLengthCm and PetalWidthCm of all flowers

# %%
plt.subplots(figsize=(10,7))
sns.boxplot(data=iris).set_title("Distribution of Sepal_length, Sepal_width, petal_length and petal_width of 3 flowers")
plt.show()

# %% [markdown]
# 2.4 Violin

# %% [markdown]
# ***
# Violin Plot is a method to visualize the distribution of numerical data of different variables. It is similar to Box Plot but with a rotated plot on each side, giving more information about the density estimate on the y-axis. The density is mirrored and flipped over and the resulting shape is filled in, creating an image resembling a violin. The advantage of a violin plot is that it can show nuances in the distribution that aren’t perceptible in a boxplot. On the other hand, the boxplot more clearly shows the outliers in the data.
# ***

# %% [markdown]
# #### 1(j)
# rubric={points:1}
#
# Make a violin plot for each of the four features over the three species. The y axis is the feature and x axis is the three species
#
# Hint: use violinplot in Seaborn

# %% [markdown]
# <div class="alert alert-warning">
#
# Solution_1(j)
#
# </div>

# %%
sns.violinplot(data = splot, x = "Species", y = "SepalLengthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.violinplot(data = splot, x = "Species", y = "SepalWidthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.violinplot(data = splot, x = "Species", y = "PetalLengthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.violinplot(data = splot, x = "Species", y = "PetalWidthCm")
# Out:
# <AxesSubplot: xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# #### Show both shape and point of the data

# %%
plt.subplots(figsize=(10,7))
sns.violinplot(data=iris)
sns.swarmplot( data=iris)
plt.show()

# %% [markdown]
# 2.5 Area Plot

# %% [markdown]
# ***
# Area Plot gives us a visual representation of Various dimensions of Iris flower and their range in dataset.
# ***

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));

# %% [markdown]
# 2.6 Correlation

# %% [markdown]
# #![Getting Started](correlation-examples.svg)

# %%
iris.corr()
# Out:
# C:\Users\kinzi\AppData\Local\Temp\ipykernel_380\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.117570       0.871754      0.817941
# SepalWidthCm       -0.117570      1.000000      -0.428440     -0.366126
# PetalLengthCm       0.871754     -0.428440       1.000000      0.962865
# PetalWidthCm        0.817941     -0.366126       0.962865      1.000000

# %% [markdown]
# #### Heatmap of correlation data

# %%
plt.subplots(figsize = (8,8))
sns.heatmap(iris.corr(),annot=True,fmt="f").set_title("Corelation of attributes (petal length,width and sepal length,width) among Iris species")
plt.show()
# Out:
# C:\Users\kinzi\AppData\Local\Temp\ipykernel_380\2349058561.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),annot=True,fmt="f").set_title("Corelation of attributes (petal length,width and sepal length,width) among Iris species")

# %% [markdown]
# The Sepal Width and Length are not correlated, whereas the Petal Width and Length are highly correlated

# %% [markdown]
# Congratulations for completing the Homework Assignment 0. Way to go!!
